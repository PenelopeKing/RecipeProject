# %% [markdown]
# https://www.kaggle.com/datasets/paultimothymooney/recipenlg?resource=download&select=RecipeNLG_dataset.csv

# %%
# importing libraries and packages
import pandas as pd
import numpy as np

# %%
# load in the dataset as raw_df, delete extraneous column
# (!) dataset is extracted from outside of this workspace
# stored only on my computer for now
raw_df = pd.read_csv(r'/Users/penelopeking/Desktop/RecipeProject_Data/\
    RecipeNLG_dataset.csv')
raw_df = raw_df.drop(columns = ['Unnamed: 0'])
raw_df
# Out:
#                                                  title  \
# 0                                  No-Bake Nut Cookies
# 1                                Jewell Ball'S Chicken
# 2                                          Creamy Corn
# 3                                        Chicken Funny
# 4                                 Reeses Cups(Candy)
# ...                                                ...
# 2231137                            Sunny's Fake Crepes
# 2231138                                     Devil Eggs
# 2231139  Extremely Easy and Quick - Namul Daikon Salad
# 2231140     Pan-Roasted Pork Chops With Apple Fritters
# 2231141                 Polpette in Spicy Tomato Sauce
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# ...

# %%
df= raw_df.get(['title','ingredients','link','NER'])
df
# Out:
#                                                  title  \
# 0                                  No-Bake Nut Cookies
# 1                                Jewell Ball'S Chicken
# 2                                          Creamy Corn
# 3                                        Chicken Funny
# 4                                 Reeses Cups(Candy)
# ...                                                ...
# 2231137                            Sunny's Fake Crepes
# 2231138                                     Devil Eggs
# 2231139  Extremely Easy and Quick - Namul Daikon Salad
# 2231140     Pan-Roasted Pork Chops With Apple Fritters
# 2231141                 Polpette in Spicy Tomato Sauce
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# ...

# %%
col = list(raw_df.columns)
col
# Out:
# ['title', 'ingredients', 'directions', 'link', 'source', 'NER']

# %%
in_csv = 'datasets/recipe_nlg/RecipeNLG_dataset.csv'
num_lines  = sum (1 for row in (open(in_csv)))
row_size = 40_000
i = 1000

df = pd.read_csv(in_csv, nrows = row_size, skiprows = i, names=col)
df.get(['title','ingredients','link','NER'])
# Out:
#                                      title  \
# 999                            Peach Salad
# 1000   Hidden Valley Ranch Oyster Crackers
# 1001                        Pepperoni Loaf
# 1002                       Animal Crackers
# 1003                            Sauerkraut
# ...                                    ...
# 40994                             Pea Soup
# 40995                            Plum Cake
# 40996                    Braised Beef Tips
# 40997                              Stollen
# 40998                  Pineapple Casserole
#
#                                              ingredients  \
# 999    ["2-3 oz boxes Peach Jello", "1 large jar Peac...
# 1000   ["12 to 16 oz. plain oyster crackers", "1 pkg....
# 1001   ["1 frozen loaf bread, let thaw overnight", "1...
# 1002   ["1/2 c. oatmeal", "2 tsp. honey", "1/4 plus 1...
# 1003   ["1 can kraut, drained", "1 c. water", "3 stri...
# ...                                                  ...
# ...
